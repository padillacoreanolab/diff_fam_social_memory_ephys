# %%
import spike.spike_analysis.spike_collection as sc
import spike.spike_analysis.spike_recording as sr
import spike.spike_analysis.firing_rate_calculations as fr
import spike.spike_analysis.normalization as norm
import spike.spike_analysis.single_cell as single_cell
import spike.spike_analysis.spike_collection as collection
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import behavior.boris_extraction as boris
import matplotlib.pyplot as plt
import pickle
import re

# %%
pd.set_option('display.max_colwidth', 0)  # 0 means unlimited in newer pandas versions

# Show all rows
pd.set_option("display.max_rows", None)

# Show all columns
pd.set_option("display.max_columns", None)

# Don’t truncate column contents
pd.set_option("display.max_colwidth", None)

# Expand the display to the full width of the screen
pd.set_option("display.width", 0)

# %%
spike_collection_json_path = r'C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\spike_collection.json\spike_collection.json'

# %%
import importlib
import spike.spike_analysis.spike_collection as sc

importlib.reload(sc)
# Out:
# <module 'spike.spike_analysis.spike_collection' from 'c:\\Users\\thoma\\Code\\ResearchCode\\diff_fam_social_memory_ephys\\spike\\spike_analysis\\spike_collection.py'>

# %%
new_sp = sc.SpikeCollection.load_collection(spike_collection_json_path)

# %%
rec1 = new_sp.recordings[0].event_dict.keys()

# %%
def table_of_events_neurons_per_rec(spike_collection):
    """
    Returns a table with # of total neurons in recording and # of each event type or event_dict keys.
    """
    rows = []
    for rec in spike_collection.recordings:
        # Get the number of neurons in the recording
        num_neurons = rec.good_neurons

        # Get the number of events for each event type
        event_counts = {event: len(rec.event_dict[event]) for event in rec.event_dict.keys()}

        # Create a row for the table
        row = {
            'recording': rec.name,
            'num_neurons': num_neurons,
            **event_counts
        }

        # Collect rows in a list instead of using append()
        rows.append(row)

    # Create the DataFrame at the end
    table = pd.DataFrame(rows, columns=[
        'recording', 'num_neurons', 'alone_rewarded', 'alone_rewarded_baseline', 'high_comp',
        'high_comp_lose', 'high_comp_lose_baseline', 'high_comp_win', 'high_comp_win_baseline',
        'lose', 'low_comp', 'low_comp_lose', 'low_comp_lose_baseline', 'low_comp_win',
        'low_comp_win_baseline', 'overall_pretone', 'win'
    ])
    
    return table

# Usage
table = table_of_events_neurons_per_rec(new_sp)
table.head(len(table))
# Out:
#                                                                        recording  \
# 0    20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec
# 1    20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
# 2    20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec
# 3    20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec
# 4    20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec
# 5    20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec
# 6    20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec
# 7    20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec
# 8    20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec
# 9    20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec
# 10   20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
# 11   20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec
# 12   20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec
# 13   20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec
# 14   20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec
# 15  20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec
# 16  20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec
# 17   20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec
# 18                            20240317_151922_long_comp_subj_3-1_t6b6_merged.rec
# 19                            20240317_151922_long_comp_subj_3-3_t5b5_merged.rec
# 20                            20240317_172017_long_comp_subj_4-2_t6b6_merged.rec
# 21                            20240317_172017_long_comp_subj_4-3_t5b5_merged.rec
# 22                            20240318_143819_long_comp_subj_3-3_t6b6_merged.rec
# 23                            20240318_143819_long_comp_subj_3-4_t5b5_merged.rec
# 24                            20240318_170933_long_comp_subj_4-3_t6b6_merged.rec
# 25                            20240319_160457_long_comp_subj_4-2_t5b5_merged.rec
# 26                            20240320_114629_long_comp_subj_5-3_t6b6_merged.rec
# 27                           20240320_142408_alone_comp_subj_3-1_t6b6_merged.rec
# 28                           20240320_142408_alone_comp_subj_3-3_t5b5_merged.rec
# 29                           20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec
# 30                           20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec
# 31                            20240321_114851_long_comp_subj_5-3_t5b5_merged.rec
# 32                           20240322_120625_alone_comp_subj_3-3_t6b6_merged.rec
# 33                           20240322_120625_alone_comp_subj_3-4_t5b5_merged.rec
# 34                           20240322_160946_alone_comp_subj_4-3_t6b6_merged.rec
# 35                           20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec
# 36                           20240323_144517_alone_comp_subj_3-1_t5b5_merged.rec
# 37                           20240323_144517_alone_comp_subj_3-4_t6b6_merged.rec
# 38                           20240323_165815_alone_comp_subj_4-2_t5b5_merged.rec
#
#     num_neurons  alone_rewarded  alone_rewarded_baseline  high_comp  \
# 0            22              40                       40          9
# 1            10              40                       40          9
# 2            15              40                       40         14
# 3            20              40                       40         14
# 4            15              40                        0         11
# 5            37              40                        0         11
# 6            31              38                       38         14
# 7            27              38                       38         14
# 8            19              39                       39         11
# 9            15              39                       39         11
# 10           18               0                        0         15
# 11           29               0                        0         15
# 12           21               0                        0          9
# 13           12               0                        0          9
# 14           18               0                        0         12
# 15           10               0                        0         11
# 16           28               0                        0         11
# 17           20               0                        0         10
# 18            7               0                        0         28
# 19           13               0                        0         28
# 20           11               0                        0         36
# 21           22               0                        0         36
# 22           23               0                        0         15
# 23            6               0                        0         15
# 24           24               0                        0         33
# 25           18               0                        0          9
# 26            4               0                        0         31
# 27           15              42                        1         11
# 28           10              42                        1         11
# 29            6              42                        0         11
# 30           23              42                        0         11
# 31            8               0                        0         33
# 32           15              42                        0         15
# 33            7              42                        0         15
# 34           24              42                        0         17
# 35            6              42                        0         16
# 36           14              42                        1         17
# 37            9              42                        1         17
# 38           17              42                        2         10
#
#     high_comp_lose  high_comp_lose_baseline  high_comp_win  \
# 0                1                       40              8
# 1                8                       40              1
# 2               10                       40              4
# 3                4                       40             10
# 4                0                        0             11
# 5               11                        0              0
# 6                5                       38              9
# 7                9                       38              5
# 8                1                       39             10
# 9               10                       39              1
# 10               1                        0             14
# 11              14                        0              1
# 12               3                        0              6
# 13               6                        0              3
# 14              12                        0              0
# 15               4                        0              7
# 16               7                        0              4
# 17              10                       10              0
# 18              12                        0             16
# 19              16                        0             12
# 20              30                        0              6
# 21               6                        0             30
# 22              15                        0              0
# 23               0                        0             15
# 24               4                        0             29
# 25               1                        0              8
# 26              11                        0             20
# 27               2                        1              9
# 28               9                        1              2
# 29              11                        0              0
# 30               0                        0             11
# 31               6                        0             27
# 32              14                        0              1
# 33               1                        0             14
# 34               1                        0             16
# 35              16                        0              0
# 36              16                        1              1
# 37               1                        1             16
# 38               7                        2              3
#
#     high_comp_win_baseline  lose  low_comp  low_comp_lose  \
# 0                       40     7        11              6
# 1                       40    13        11              5
# 2                       40    13         6              3
# 3                       40     7         6              3
# 4                        0     1         9              1
# 5                        0    19         9              8
# 6                       38     6         6              1
# 7                       38    14         6              5
# 8                       39     6         9              5
# 9                       39    14         9              4
# 10                       0     2         6              1
# 11                       0    19         6              5
# 12                       0     6        11              3
# 13                       0    14        11              8
# 14                       0    15         7              3
# 15                       0     4         6              0
# 16                       0    13         6              6
# 17                       0    18        10              8
# 18                       0    12         2              0
# 19                       0    18         2              2
# 20                       0    33         3              3
# 21                       0     6         3              0
# 22                       0    41        26             26
# 23                       0     0        26              0
# 24                       0     4         6              0
# 25                       0     1        30              0
# 26                       0    14         9              3
# 27                       1     8         9              6
# 28                       1    12         9              3
# 29                       0    19         8              8
# 30                       0     0         8              0
# 31                       0     6         1              0
# 32                       0    20         6              6
# 33                       0     1         6              0
# 34                       0     1         4              0
# 35                       0    19         3              3
# 36                       1    17         2              1
# 37                       1     2         2              1
# 38                       2    10         6              3
#
#     low_comp_lose_baseline  low_comp_win  low_comp_win_baseline  \
# 0                       40             5                     40
# 1                       40             6                     40
# 2                       40             3                     40
# 3                       40             3                     40
# 4                        0             8                      0
# 5                        0             1                      0
# 6                       38             5                     38
# 7                       38             1                     38
# 8                       39             4                     39
# 9                       39             5                     39
# 10                       0             5                      0
# 11                       0             1                      0
# 12                       0             8                      0
# 13                       0             3                      0
# 14                       0             4                      0
# 15                       0             6                      0
# 16                       0             0                      0
# 17                       8             2                      2
# 18                       0             2                      0
# 19                       0             0                      0
# 20                       0             0                      0
# 21                       0             3                      0
# 22                       0             0                      0
# 23                       0            26                      0
# 24                       0             6                      0
# 25                       0            30                      0
# 26                       0             6                      0
# 27                       1             3                      1
# 28                       1             6                      1
# 29                       0             0                      0
# 30                       0             8                      0
# 31                       0             1                      0
# 32                       0             0                      0
# 33                       0             6                      0
# 34                       0             4                      0
# 35                       0             0                      0
# 36                       1             1                      1
# 37                       1             1                      1
# 38                       2             3                      2
#
#     overall_pretone  win
# 0             160.0   13
# 1             160.0    7
# 2             160.0    7
# 3             160.0   13
# 4               NaN   19
# 5               NaN    1
# 6             152.0   14
# 7             152.0    6
# 8             156.0   14
# 9             156.0    6
# 10              NaN   19
# 11              NaN    2
# 12              NaN   14
# 13              NaN    6
# 14              NaN    4
# 15              NaN   13
# 16              NaN    4
# 17             20.0    2
# 18              NaN   18
# 19              NaN   12
# 20              NaN    6
# 21              NaN   33
# 22              NaN    0
# 23              NaN   41
# 24              NaN   35
# 25              NaN   38
# 26              NaN   26
# 27              4.0   12
# 28              4.0    8
# 29              NaN    0
# 30              NaN   19
# 31              NaN   28
# 32              NaN    1
# 33              NaN   20
# 34              NaN   20
# 35              NaN    0
# 36              4.0    2
# 37              4.0   17
# 38              8.0    6

# %%
def summarize_event_criteria_by_recording(table):
    """
    For each recording, returns a dictionary with:
    - 'recording': name
    - 'qualifying_events': list of event columns that meet threshold
    - 'num_qualifying_events': count of such columns
    """
    skip_cols = {'recording', 'num_neurons', 'overall_pretone', 'lose', 'win'}
    summaries = []

    for _, row in table.iterrows():
        qualifying_events = []
        sum_of_trials = 0

        # skip row if win is less than 2
        if row['win'] <= 3:
            continue

        for col in table.columns:
            if col in skip_cols:
                continue
            elif row[col] >= 3:
                qualifying_events.append(col)
                sum_of_trials += row[col]
                num_neurons = row['num_neurons']
                

        summaries.append({
            'recording': row['recording'],
            'qualifying_events': qualifying_events,
            'num_qualifying_events_types': len(qualifying_events),
            'sum_of__qualifying_trials': sum_of_trials,
            'num_neurons': num_neurons,
            'num_wins': row['win']
        })

    return pd.DataFrame(summaries)

# Usage
event_summary = summarize_event_criteria_by_recording(table)
event_summary.head(len(event_summary))
# Out:
#                                                                        recording  \
# 0    20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec
# 1    20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
# 2    20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec
# 3    20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec
# 4    20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec
# 5    20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec
# 6    20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec
# 7    20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec
# 8    20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec
# 9    20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
# 10   20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec
# 11   20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec
# 12   20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec
# 13  20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec
# 14  20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec
# 15                            20240317_151922_long_comp_subj_3-1_t6b6_merged.rec
# 16                            20240317_151922_long_comp_subj_3-3_t5b5_merged.rec
# 17                            20240317_172017_long_comp_subj_4-2_t6b6_merged.rec
# 18                            20240317_172017_long_comp_subj_4-3_t5b5_merged.rec
# 19                            20240318_143819_long_comp_subj_3-4_t5b5_merged.rec
# 20                            20240318_170933_long_comp_subj_4-3_t6b6_merged.rec
# 21                            20240319_160457_long_comp_subj_4-2_t5b5_merged.rec
# 22                            20240320_114629_long_comp_subj_5-3_t6b6_merged.rec
# 23                           20240320_142408_alone_comp_subj_3-1_t6b6_merged.rec
# 24                           20240320_142408_alone_comp_subj_3-3_t5b5_merged.rec
# 25                           20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec
# 26                            20240321_114851_long_comp_subj_5-3_t5b5_merged.rec
# 27                           20240322_120625_alone_comp_subj_3-4_t5b5_merged.rec
# 28                           20240322_160946_alone_comp_subj_4-3_t6b6_merged.rec
# 29                           20240323_144517_alone_comp_subj_3-4_t6b6_merged.rec
# 30                           20240323_165815_alone_comp_subj_4-2_t5b5_merged.rec
#
#                                                                                                                                                                                                              qualifying_events  \
# 0                   [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 1                  [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 2   [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 3   [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 4                                                                                                                                                           [alone_rewarded, high_comp, high_comp_win, low_comp, low_comp_win]
# 5                  [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 6                 [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win_baseline]
# 7                   [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose_baseline, high_comp_win, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 8                  [alone_rewarded, alone_rewarded_baseline, high_comp, high_comp_lose, high_comp_lose_baseline, high_comp_win_baseline, low_comp, low_comp_lose, low_comp_lose_baseline, low_comp_win, low_comp_win_baseline]
# 9                                                                                                                                                                           [high_comp, high_comp_win, low_comp, low_comp_win]
# 10                                                                                                                                           [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose, low_comp_win]
# 11                                                                                                                                           [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose, low_comp_win]
# 12                                                                                                                                                          [high_comp, high_comp_lose, low_comp, low_comp_lose, low_comp_win]
# 13                                                                                                                                                          [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_win]
# 14                                                                                                                                                         [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose]
# 15                                                                                                                                                                                  [high_comp, high_comp_lose, high_comp_win]
# 16                                                                                                                                                                                  [high_comp, high_comp_lose, high_comp_win]
# 17                                                                                                                                                         [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose]
# 18                                                                                                                                                          [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_win]
# 19                                                                                                                                                                          [high_comp, high_comp_win, low_comp, low_comp_win]
# 20                                                                                                                                                          [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_win]
# 21                                                                                                                                                                          [high_comp, high_comp_win, low_comp, low_comp_win]
# 22                                                                                                                                           [high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose, low_comp_win]
# 23                                                                                                                                           [alone_rewarded, high_comp, high_comp_win, low_comp, low_comp_lose, low_comp_win]
# 24                                                                                                                                          [alone_rewarded, high_comp, high_comp_lose, low_comp, low_comp_lose, low_comp_win]
# 25                                                                                                                                                          [alone_rewarded, high_comp, high_comp_win, low_comp, low_comp_win]
# 26                                                                                                                                                                                  [high_comp, high_comp_lose, high_comp_win]
# 27                                                                                                                                                          [alone_rewarded, high_comp, high_comp_win, low_comp, low_comp_win]
# 28                                                                                                                                                          [alone_rewarded, high_comp, high_comp_win, low_comp, low_comp_win]
# 29                                                                                                                                                                                  [alone_rewarded, high_comp, high_comp_win]
# 30                                                                                                                           [alone_rewarded, high_comp, high_comp_lose, high_comp_win, low_comp, low_comp_lose, low_comp_win]
#
#     num_qualifying_events_types  sum_of__qualifying_trials  num_neurons  \
# 0                            11                        279           22
# 1                            11                        279           10
# 2                            12                        280           15
# 3                            12                        280           20
# 4                             5                         79           15
# 5                            11                        267           31
# 6                            11                        267           27
# 7                            11                        273           19
# 8                            11                        273           15
# 9                             4                         40           18
# 10                            6                         40           21
# 11                            6                         40           12
# 12                            5                         38           18
# 13                            5                         34           10
# 14                            5                         34           28
# 15                            3                         56            7
# 16                            3                         56           13
# 17                            5                         78           11
# 18                            5                         78           22
# 19                            4                         82            6
# 20                            5                         78           24
# 21                            4                         77           18
# 22                            6                         80            4
# 23                            6                         80           15
# 24                            6                         80           10
# 25                            5                         80           23
# 26                            3                         66            8
# 27                            5                         83            7
# 28                            5                         83           24
# 29                            3                         75            9
# 30                            7                         74           17
#
#     num_wins
# 0         13
# 1          7
# 2          7
# 3         13
# 4         19
# 5         14
# 6          6
# 7         14
# 8          6
# 9         19
# 10        14
# 11         6
# 12         4
# 13        13
# 14         4
# 15        18
# 16        12
# 17         6
# 18        33
# 19        41
# 20        35
# 21        38
# 22        26
# 23        12
# 24         8
# 25        19
# 26        28
# 27        20
# 28        20
# 29        17
# 30         6

# %%
# calculate the total sum of qualifying trials across all recordings
total_sum_of_qualifying_trials = event_summary['sum_of__qualifying_trials'].sum()
print(f"Total sum of qualifying trials across all recordings: {total_sum_of_qualifying_trials}")

# total number of qualifying event types
total_num_qualifying_event_types = event_summary['num_qualifying_events_types'].sum()
print(f"Total number of qualifying event types across all recordings: {total_num_qualifying_event_types}")

# sum of neurons across all recordings
total_num_neurons = event_summary['num_neurons'].sum()
print(f"Total number of neurons across all recordings: {total_num_neurons}")


# count number of times each event is in qualifying events
def count_event_occurrences(event_summary):
    """
    Counts how many times each event type appears in the qualifying events across all recordings.
    """
    event_counts = {}

    for _, row in event_summary.iterrows():
        for event in row['qualifying_events']:
            if event not in event_counts:
                event_counts[event] = 0
            event_counts[event] += 1

    return pd.DataFrame(event_counts.items(), columns=['event', 'count'])

# Usage
event_occurrences = count_event_occurrences(event_summary)
event_occurrences = event_occurrences.sort_values(by='count', ascending=False)
event_occurrences.head(len(event_occurrences))
event_occurrences.head(20)
# Out:
# Total sum of qualifying trials across all recordings: 3709
# Total number of qualifying event types across all recordings: 201
# Total number of neurons across all recordings: 499
#                       event  count
# 2                 high_comp     31
# 4             high_comp_win     27
# 6                  low_comp     27
# 9              low_comp_win     24
# 11           high_comp_lose     20
# 7             low_comp_lose     16
# 0            alone_rewarded     16
# 1   alone_rewarded_baseline      8
# 3   high_comp_lose_baseline      8
# 5    high_comp_win_baseline      8
# 8    low_comp_lose_baseline      8
# 10    low_comp_win_baseline      8

# %%
trial_types = [
    'alone_rewarded', 'alone_rewarded_baseline', 'high_comp',
    'high_comp_lose', 'high_comp_lose_baseline', 'high_comp_win',
    'high_comp_win_baseline', 'low_comp', 'low_comp_lose',
    'low_comp_lose_baseline', 'low_comp_win', 'low_comp_win_baseline'
]

def total_neurons_per_trial_type(event_summary, trial_types):
    """
    Returns a dictionary with the total number of neurons for each trial type
    across all recordings, using 'qualifying_events' like a set.
    """
    total_neurons = {trial_type: 0 for trial_type in trial_types}

    for _, row in event_summary.iterrows():
        num_neurons = row['num_neurons']
        qualifying_events = row['qualifying_events']  # should be a list

        for trial_type in trial_types:
            if trial_type in qualifying_events:
                total_neurons[trial_type] += num_neurons

    return total_neurons


# Usage
total_neurons = total_neurons_per_trial_type(event_summary, trial_types)
# Display the total number of neurons for each trial type
for trial_type, count in total_neurons.items():
    print(f"Total neurons for {trial_type}: {count}")
# Out:
# Total neurons for alone_rewarded: 279
# Total neurons for alone_rewarded_baseline: 159
# Total neurons for high_comp: 499
# Total neurons for high_comp_lose: 323
# Total neurons for high_comp_lose_baseline: 159
# Total neurons for high_comp_win: 446
# Total neurons for high_comp_win_baseline: 159
# Total neurons for low_comp: 462
# Total neurons for low_comp_lose: 264
# Total neurons for low_comp_lose_baseline: 159
# Total neurons for low_comp_win: 396
# Total neurons for low_comp_win_baseline: 159

# %%
# save table to csv and put in the same directory 
table.to_csv('spike_collection_event_counts.csv', index=False)

# %%
event_summary.to_csv('event_summary.csv', index=False)

# %%
len(new_sp.recordings)
# Out:
# 39

# %%
def filter_recordings_by_event_counts(table):
    """
    Filters the table to include only recordings that have:
    - >= 3 trials for every event type (except specified columns),
    - > 1 trial for 'win',
    - Skips 'recording', 'num_neurons', 'overall_pretone'.
    Includes debug printouts for unexpected types or values.
    """
    skip_cols = {'recording', 'num_neurons', 'overall_pretone'}
    no_wins = 0
    no_losses = 0
    no_alone_rewarded = 0

    no_wins_recordings = []
    no_losses_recordings = []
    no_alone_rewarded_recordings = []
    
    # Print column names at the start
    print("\n=== Column Names ===")
    print(list(table.columns))
    print("====================\n")

    for index, row in table.iterrows():

        for col in table.columns:
            if col in skip_cols:
                continue

            value = row[col]

            if col == 'win':
                if pd.isna(value):
                    print(f"    [WARN] 'win' is NaN for recording: {row.get('recording', 'N/A')}")
                elif value == 0:
                    print(f"\n    [INFO] no wins for recording: {row.get('recording', 'N/A')}")
                    no_wins += 1
                    no_wins_recordings.append(row.get('recording', 'N/A'))

                if value <= 1:
                    print()
                    print(f"    [FAIL] Not enough wins: {value} (<= 1) for {row.get('recording', 'N/a')} \n")


            elif col == 'lose':
                if pd.isna(value):
                    print(f"    [WARN] 'lose' is NaN for recording: {row.get('recording', 'N/A')}")
                elif value == 0:
                    print(f"    [INFO] no losses for recording: {row.get('recording', 'N/A')}")
                    no_losses += 1
                    no_losses_recordings.append(row.get('recording', 'N/A'))


            elif col == 'alone_rewarded':
                if pd.isna(value):
                    print(f"    [WARN] 'alone_rewarded' is NaN for recording: {row.get('recording', 'N/A')}")
                elif value == 0:
                    print(f"    [INFO] no alone_rewarded for recording: {row.get('recording', 'N/A')}")
                    no_alone_rewarded += 1
                    no_alone_rewarded_recordings.append(row.get('recording', 'N/A'))

    print(f"Number of recordings with no wins: {no_wins}")
    print(f"Number of recordings with no losses: {no_losses}")
    print(f"Number of recordings with no alone_rewarded: {no_alone_rewarded}")
    print(f"Recordings with no wins: {no_wins_recordings}")
    print(f"Recordings with no losses: {no_losses_recordings}")
    print(f"Recordings with no alone_rewarded: {no_alone_rewarded_recordings}")


filter_recordings_by_event_counts(table)
# Out:
# === Column Names ===
# ['recording', 'num_neurons', 'alone_rewarded', 'alone_rewarded_baseline', 'high_comp', 'high_comp_lose', 'high_comp_lose_baseline', 'high_comp_win', 'high_comp_win_baseline', 'lose', 'low_comp', 'low_comp_lose', 'low_comp_lose_baseline', 'low_comp_win', 'low_comp_win_baseline', 'overall_pretone', 'win']
# ====================
#
#
#     [FAIL] Not enough wins: 1 (<= 1) for 20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec
#
#     [INFO] no alone_rewarded for recording: 20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
#     [INFO] no alone_rewarded for recording: 20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec
#     [INFO] no alone_rewarded for recording: 20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec
#     [INFO] no alone_rewarded for recording: 20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec
#     [INFO] no alone_rewarded for recording: 20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec
#     [INFO] no alone_rewarded for recording: 20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec
#     [INFO] no alone_rewarded for recording: 20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec
#     [INFO] no alone_rewarded for recording: 20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec
#     [INFO] no alone_rewarded for recording: 20240317_151922_long_comp_subj_3-1_t6b6_merged.rec
#     [INFO] no alone_rewarded for recording: 20240317_151922_long_comp_subj_3-3_t5b5_merged.rec
#     [INFO] no alone_rewarded for recording: 20240317_172017_long_comp_subj_4-2_t6b6_merged.rec
#     [INFO] no alone_rewarded for recording: 20240317_172017_long_comp_subj_4-3_t5b5_merged.rec
#     [INFO] no alone_rewarded for recording: 20240318_143819_long_comp_subj_3-3_t6b6_merged.rec
#
#     [INFO] no wins for recording: 20240318_143819_long_comp_subj_3-3_t6b6_merged.rec
#
#     [FAIL] Not enough wins: 0 (<= 1) for 20240318_143819_long_comp_subj_3-3_t6b6_merged.rec
#
#     [INFO] no alone_rewarded for recording: 20240318_143819_long_comp_subj_3-4_t5b5_merged.rec
#     [INFO] no losses for recording: 20240318_143819_long_comp_subj_3-4_t5b5_merged.rec
#     [INFO] no alone_rewarded for recording: 20240318_170933_long_comp_subj_4-3_t6b6_merged.rec
#     [INFO] no alone_rewarded for recording: 20240319_160457_long_comp_subj_4-2_t5b5_merged.rec
#     [INFO] no alone_rewarded for recording: 20240320_114629_long_comp_subj_5-3_t6b6_merged.rec
#
#     [INFO] no wins for recording: 20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec
#
#     [FAIL] Not enough wins: 0 (<= 1) for 20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec
#
#     [INFO] no losses for recording: 20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec
#     [INFO] no alone_rewarded for recording: 20240321_114851_long_comp_subj_5-3_t5b5_merged.rec
#
#     [FAIL] Not enough wins: 1 (<= 1) for 20240322_120625_alone_comp_subj_3-3_t6b6_merged.rec
#
#
#     [INFO] no wins for recording: 20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec
#
#     [FAIL] Not enough wins: 0 (<= 1) for 20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec
#
# Number of recordings with no wins: 3
# Number of recordings with no losses: 2
# Number of recordings with no alone_rewarded: 18
# Recordings with no wins: ['20240318_143819_long_comp_subj_3-3_t6b6_merged.rec', '20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec', '20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec']
# Recordings with no losses: ['20240318_143819_long_comp_subj_3-4_t5b5_merged.rec', '20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec']
# Recordings with no alone_rewarded: ['20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec', '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec', '20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec', '20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec', '20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec', '20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec', '20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec', '20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec', '20240317_151922_long_comp_subj_3-1_t6b6_merged.rec', '20240317_151922_long_comp_subj_3-3_t5b5_merged.rec', '20240317_172017_long_comp_subj_4-2_t6b6_merged.rec', '20240317_172017_long_comp_subj_4-3_t5b5_merged.rec', '20240318_143819_long_comp_subj_3-3_t6b6_merged.rec', '20240318_143819_long_comp_subj_3-4_t5b5_merged.rec', '20240318_170933_long_comp_subj_4-3_t6b6_merged.rec', '20240319_160457_long_comp_subj_4-2_t5b5_merged.rec', '20240320_114629_long_comp_subj_5-3_t6b6_merged.rec', '20240321_114851_long_comp_subj_5-3_t5b5_merged.rec']

# %%
# loop through rows in table, create column with true/false for each row that has event types >= 3 trials and > 1 win
def filter_recordings_by_event_counts(table):
    """
    Filters the table to include only recordings that have:
    - >= 3 trials for every event type (except specified columns),
    - > 1 trial for 'win',
    - Skips 'recording', 'num_neurons', 'overall_pretone'.
    """
    skip_cols = {'recording', 'num_neurons', 'overall_pretone'}
    filtered_rows = []

    for _, row in table.iterrows():
        meets_criteria = True
        for col in table.columns:
            if col in skip_cols:
                continue
            elif col == 'win':
                if row[col] == 0:
                    print(f"\nno wins for recording: {row['recording']}\n")
                if row[col] <= 1:
                    meets_criteria = False
                    break
            elif col == 'lose':
                if row[col] == 0:
                    print(f"\nno losses for recording: {row['recording']}\n")
            elif col == 'alone_rewarded':
                if row[col] == 0:
                    print(f"no alone_rewarded for recording: {row['recording']}")
            elif row[col] < 3:
                meets_criteria = False
                break
        
        if meets_criteria:
            filtered_rows.append(row)

    return pd.DataFrame(filtered_rows)

# Usage
filtered_table = filter_recordings_by_event_counts(table)
filtered_table.head(20)
# Out:
# no alone_rewarded for recording: 20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
# no alone_rewarded for recording: 20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec
# no alone_rewarded for recording: 20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec
# no alone_rewarded for recording: 20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec
# no alone_rewarded for recording: 20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec
# no alone_rewarded for recording: 20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec
# no alone_rewarded for recording: 20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec
# no alone_rewarded for recording: 20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec
# no alone_rewarded for recording: 20240317_151922_long_comp_subj_3-1_t6b6_merged.rec
# no alone_rewarded for recording: 20240317_151922_long_comp_subj_3-3_t5b5_merged.rec
# no alone_rewarded for recording: 20240317_172017_long_comp_subj_4-2_t6b6_merged.rec
# no alone_rewarded for recording: 20240317_172017_long_comp_subj_4-3_t5b5_merged.rec
# no alone_rewarded for recording: 20240318_143819_long_comp_subj_3-3_t6b6_merged.rec
# no alone_rewarded for recording: 20240318_143819_long_comp_subj_3-4_t5b5_merged.rec
# no alone_rewarded for recording: 20240318_170933_long_comp_subj_4-3_t6b6_merged.rec
# no alone_rewarded for recording: 20240319_160457_long_comp_subj_4-2_t5b5_merged.rec
# no alone_rewarded for recording: 20240320_114629_long_comp_subj_5-3_t6b6_merged.rec
# no alone_rewarded for recording: 20240321_114851_long_comp_subj_5-3_t5b5_merged.rec
#                                                                      recording  \
# 2  20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec
# 3  20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec
#
#    num_neurons  alone_rewarded  alone_rewarded_baseline  high_comp  \
# 2           15              40                       40         14
# 3           20              40                       40         14
#
#    high_comp_lose  high_comp_lose_baseline  high_comp_win  \
# 2              10                       40              4
# 3               4                       40             10
#
#    high_comp_win_baseline  lose  low_comp  low_comp_lose  \
# 2                      40    13         6              3
# 3                      40     7         6              3
#
#    low_comp_lose_baseline  low_comp_win  low_comp_win_baseline  \
# 2                      40             3                     40
# 3                      40             3                     40
#
#    overall_pretone  win
# 2            160.0    7
# 3            160.0   13

# %%
def table_of_events_neurons_per_rec(spike_collection):
    """
    Returns a table with:
    - # of total neurons in recording
    - # of events of each type
    - # of neurons that have at least 3 trials for *every* event type
    """
    rows = []
    for rec in spike_collection.recordings:
        num_neurons = rec.good_neurons

        # Count how many events of each type (all neurons combined)
        event_counts = {event: len(rec.event_dict[event]) for event in rec.event_dict.keys()}

        print('\nEvent counts for recording {}: {}\n'.format(rec.name, event_counts))

        # Now filter neurons that have >= 3 events in EACH event type
        qualifying_neurons = 0
        for neuron_id in range(num_neurons):
            meets_criteria = True
            for event_type, event_trials in rec.event_dict.items():
                # Count how many trials for this neuron
                print(f"\nChecking neuron {neuron_id} for event type '{event_type}' with {event_trials}\n")

                neuron_trials = [trial for trial in event_trials if trial['neuron'] == neuron_id]
                
                if len(neuron_trials) < 3:
                    meets_criteria = False
                    break
            if meets_criteria:
                qualifying_neurons += 1

        # Build row
        row = {
            'recording': rec.name,
            'num_neurons': num_neurons,
            'qualified_neurons_all_events_≥3': qualifying_neurons,
            **event_counts
        }

        rows.append(row)

    table = pd.DataFrame(rows)
    return table

# Usage
table = table_of_events_neurons_per_rec(new_sp)
table.head(20)
# Out:
# Event counts for recording 20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec: {'alone_rewarded': 40, 'alone_rewarded_baseline': 40, 'high_comp': 9, 'high_comp_lose': 1, 'high_comp_lose_baseline': 40, 'high_comp_win': 8, 'high_comp_win_baseline': 40, 'lose': 7, 'low_comp': 11, 'low_comp_lose': 6, 'low_comp_lose_baseline': 40, 'low_comp_win': 5, 'low_comp_win_baseline': 40, 'overall_pretone': 160, 'win': 13}
#
#
# Checking neuron 0 for event type 'alone_rewarded' with [[1849109.9  1859109.9 ]
#  [1909109.85 1919109.95]
#  [1964109.8  1974109.9 ]
#  [2029109.75 2039109.75]
#  [2084109.85 2094109.7 ]
#  [2134109.8  2144109.7 ]
#  [2184109.75 2194109.75]
#  [2289109.55 2299109.65]
#  [2409109.6  2419109.6 ]
#  [2529109.4  2539109.4 ]
#  [2639109.3  2649109.3 ]
#  [2724109.35 2734109.35]
#  [2844109.3  2854109.15]
#  [2904109.1  2914109.1 ]
#  [2969109.05 2979109.15]
#  [3029109.15 3039109.  ]
#  [3104108.95 3114109.1 ]
#  [3204108.9  3214109.  ]
#  [3299108.95 3309108.8 ]
#  [3349108.9  3359108.9 ]
#  [1849109.9  1859109.9 ]
#  [1909109.85 1919109.95]
#  [1964109.8  1974109.9 ]
#  [2029109.75 2039109.75]
#  [2084109.85 2094109.7 ]
#  [2134109.8  2144109.7 ]
#  [2184109.75 2194109.75]
#  [2289109.55 2299109.65]
#  [2409109.6  2419109.6 ]
#  [2529109.4  2539109.4 ]
#  [2639109.3  2649109.3 ]
#  [2724109.35 2734109.35]
#  [2844109.3  2854109.15]
#  [2904109.1  2914109.1 ]
#  [2969109.05 2979109.15]
#  [3029109.15 3039109.  ]
#  [3104108.95 3114109.1 ]
#  [3204108.9  3214109.  ]
#  [3299108.95 3309108.8 ]
#  [3349108.9  3359108.9 ]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[49], line 47
#      44     return table
#      46 # Usage
# ---> 47 table = table_of_events_neurons_per_rec(new_sp)
#      48 table.head(20)
#
# Cell In[49], line 25, in table_of_events_neurons_per_rec(spike_collection)
#      21 for event_type, event_trials in rec.event_dict.items():
#      22     # Count how many trials for this neuron
#      23     print(f"\nChecking neuron {neuron_id} for event type '{event_type}' with {event_trials}\n")
# ---> 25     neuron_trials = [trial for trial in event_trials if trial['neuron'] == neuron_id]
#      27     if len(neuron_trials) < 3:
#      28         meets_criteria = False
#
# Cell In[49], line 25, in <listcomp>(.0)
#      21 for event_type, event_trials in rec.event_dict.items():
#      22     # Count how many trials for this neuron
#      23     print(f"\nChecking neuron {neuron_id} for event type '{event_type}' with {event_trials}\n")
# ---> 25     neuron_trials = [trial for trial in event_trials if trial['neuron'] == neuron_id]
#      27     if len(neuron_trials) < 3:
#      28         meets_criteria = False
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
