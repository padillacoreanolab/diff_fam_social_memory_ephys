# %%
import os
import pandas as pd
import numpy as np
import pickle as pkl
from pathlib import Path
import re
import glob
import ast

# Load spreadsheets directory
spreadsheets_dir = r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\combined_excel_file.xlsx"
# spreadsheets_dir = Path("blue_npadillacoreano/npadillacoreano/share/Phy_rce2_rce3/phy_curation/eventSpreadsheets") # doesn't work for some reason
m_recs = Path("/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset")

extra_recs = [
    "20240322_160946_alone_comp_subj_4-4_t5b5_merged.rec",
    "20240323_122227_alone_comp_subj_5-3_t5b5_merged.rec",
    "20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec",
    "20240318_170933_long_comp_subj_4-4_t5b5_merged.rec",
    "20240319_160457_long_comp_subj_4-4_t6b6_merged.rec",
    "20240320_114629_long_comp_subj_5-4_t5b5_merged.rec",
    "20240321_114851_long_comp_subj_5-2_t6b6_merged.rec"
]

extra_recs = [m_recs / name for name in extra_recs]

# Optional: if you know their directory
# merged_recs = list(m_recs.glob("*.rec")) + extra_recs
merged_recs = [
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-1_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-2_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-1_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-2_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-1_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-2_t6b6_merged.rec"
]


rce2_exclude_conditions = ['temp', 'rewarded', 'omission']

# %%
rce2_spread = pd.read_excel(r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\combined_excel_file.xlsx", 
                    usecols=cols, engine='openpyxl')
rce2_spread.head()
# Out:
#   condition competition_closeness  \
# 0       NaN                   NaN
# 1       1.4           Subj 2 Only
# 2       1.3           Subj 1 Only
# 3       1.4           Subj 2 Only
# 4       1.4           Subj 2 Only
#
#                                          session_dir    all_subjects  \
# 0                                                NaN             NaN
# 1  20230612_101430_standard_comp_to_training_D1_s...  ['1.3', '1.4']
# 2  20230612_101430_standard_comp_to_training_D1_s...  ['1.3', '1.4']
# 3  20230612_101430_standard_comp_to_training_D1_s...  ['1.3', '1.4']
# 4  20230612_101430_standard_comp_to_training_D1_s...  ['1.3', '1.4']
#
#    tone_start_timestamp  tone_stop_timestamp
# 0                   NaN                  NaN
# 1              982229.0            1182226.0
# 2             3382227.0            3582224.0
# 3             5682225.0            5882222.0
# 4             7482224.0            7682221.0

# %%
rce2_after = rce2_spread.query("competition_closeness == 'After trial'")
rce2_after.head(32)
# Out:
#      condition competition_closeness  \
# 968        2.1           After trial
# 981        1.2           After trial
# 983        1.2           After trial
# 1015       2.2           After trial
# 1126       1.4           After trial
# 1131       1.4           After trial
# 1132       2.2           After trial
# 1133       1.4           After trial
# 1136       1.4           After trial
# 1184       2.2           After trial
# 1185       2.1           After trial
# 1205       2.2           After trial
# 1206       2.2           After trial
# 1207       2.2           After trial
# 1208       2.2           After trial
# 1209       2.2           After trial
# 1210       2.2           After trial
# 1211       2.2           After trial
# 1212       2.2           After trial
# 1213       2.2           After trial
# 1214       2.2           After trial
# 1215       2.2           After trial
# 1216       2.2           After trial
# 1217       2.2           After trial
# ...

# %%
len(rce2_after)
# Out:
# 32

# %%
print(merged_recs)
# Out:
# ['/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec', '/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec', '/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-3_t6b6_merged.rec', '/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-2_t6b6_merged.rec', '/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec', '/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec', '/blue/npadillacoreano/share/reward_co
# ...

# %%
'''
[PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-3_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-2_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-3_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-4_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-4_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-3_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-3_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-3_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-1_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-4_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-2_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-1_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-2_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-1_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-4_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-3_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-4_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-4_t6b6_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-4_t5b5_merged.rec'), PosixPath('/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-2_t6b6_merged.rec')]
'''

'''
paths = [
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-4_t4b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230619_115321_standard_comp_to_omission_D3_subj_1-4_t3b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_120625_alone_comp_subj_3-3_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-1_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_143819_long_comp_subj_3-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-2_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_151922_long_comp_subj_3-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-2_t3b3L_box_1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_171038_alone_comp_subj_4-2_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_144517_alone_comp_subj_3-1_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-2_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_142408_alone_comp_subj_3-1_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240322_160946_alone_comp_subj_4-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_122227_alone_comp_subj_5-3_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240323_165815_alone_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240318_170933_long_comp_subj_4-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240319_160457_long_comp_subj_4-4_t6b6_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-4_t5b5_merged.rec",
    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240321_114851_long_comp_subj_5-2_t6b6_merged.rec"
]

'''
# Out:
# '\npaths = [\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230621_111240_standard_comp_to_omission_D5_subj_1-4_t3b3L_box1_merged.rec",\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec",\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240320_114629_long_comp_subj_5-3_t6b6_merged.rec",\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20240317_172017_long_comp_subj_4-2_t6b6_merged.rec",\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230620_114347_standard_comp_to_omission_D4_subj_1-1_t1b2L_box_2_merged.rec",\n    "/blue/npadillacoreano/share/reward_comp_extention/Phy_rce2_rce3/phy_curation/megadataset/20230618_100636_standard_comp_to_omission_D2_subj_1-1_t1b2L_box2_merged.re
# ...

# %% [markdown]
# # Original event dict creation start point

# %% [markdown]
# ### This won't work with novel recordings

# %% [markdown]
# ### Matching subject to merged.rec recording

# %% [markdown]
# #### Make this work when there is no match for subject, get subj name from recording and just don't have matching merged.rec

# %%
def matchRec(rec):
    '''
    rec: filename string from session_dir (e.g. "20240317_151922_long_comp_subj_3-1_and_3-3")
    Returns: list of (formatted_subj, matching_merged_file or None) tuples, e.g., [('3.1', file1), ('3.3', None)]
    '''

    matched_subjs = []

    # Extract datetime prefix from vid rec filename
    rec_match = re.match(r"(\d{8}_\d{6})", rec)
    if not rec_match:
        print(f"{rec} not able to regex date time")
        return []

    rec_date_time = rec_match.group(1)

    # Extract subjects from the video recording name
    subj_block = re.search(r"subj_([\w\-\.\d]+)", rec)
    if not subj_block:
        print(f"{rec} does not contain valid subject block")
        return []

    raw_subjects = subj_block.group(1)
    all_subjs = re.split(r"vs|_and_|-and-|and", raw_subjects)
    video_subjs = [s.strip() for s in all_subjs if s.strip()]

    for subj in video_subjs:
        formatted = subj.replace("-", ".")
        matched_file = None

        for file in merged_recs:
            # Handle both string and Path object cases
            file_name = file if isinstance(file, str) else file.name
            if rec_date_time in file_name:
                subj_match = re.search(r"subj_([\d\-]+)", file_name)
                if subj_match:
                    merged_subj = subj_match.group(1)
                    if merged_subj == subj:
                        matched_file = os.path.basename(file_name)
                        break

        matched_subjs.append((formatted, matched_file))

    # print(f'\nmatched subjects: {matched_subjs}\n')
    return matched_subjs

# %%
def eventCondCreate(rec, df, exclude_conditions=[]):
    print("eventCondCreate ran")
    condition_dict_subj1 = {}
    condition_dict_subj2 = {}
    
    # Define all possible labels you want to guarantee exist (removed alone_rewarded)
    labels = ['high_comp_win', 'high_comp_lose', 'low_comp_lose', 'low_comp_win', 'high_comp_tie']
    
    for _, row in df.iterrows():
        cond = str(row['condition']).lower() if pd.notna(row['condition']) else ""

        # Skip excluded or empty conditions
        if not cond or pd.isna(cond) or any(ex_cond in cond for ex_cond in exclude_conditions):
            continue

        # COMPLETELY SKIP rewarded conditions - don't process them at all
        if "rewarded" in cond:
            continue

        matched_subjs = matchRec(str(row['session_dir']))
        if not matched_subjs or len(matched_subjs) < 2:
            print("\n\nERROR: no matched_subjs\n\n")
            continue
            
        #if not matched_subjs[0][0]:
         #   matched_subjs[0][0] == 
        
        subj1, subj2 = matched_subjs[0][0], matched_subjs[1][0]

        # Determine result from condition string - removed rewarded logic
        if subj1 in cond:
            subj1_result = "win"
            subj2_result = "lose"
        elif subj2 in cond:
            subj1_result = "lose"
            subj2_result = "win"
        elif "tie" in cond:
            subj1_result = "tie"
            subj2_result = "tie"
        else:
            continue
            
        # Determine label based on competition closeness
        close_str = str(row.get('competition_closeness', ''))
        '''
        error here, bad idea to make high_comp default. One other label 'After trial' exists,
        This is labeled as high comp and should've been low comp. Should check how many of these trials exist.
        '''
        comp_level = "low_comp" if "Only" in close_str else "high_comp" 
        
        subj1_label = f"{comp_level}_{subj1_result}"
        subj2_label = f"{comp_level}_{subj2_result}"

        timestamps = [int(row['tone_start_timestamp']), int(row['tone_stop_timestamp'])]

        if subj1_label not in condition_dict_subj1:
            condition_dict_subj1[subj1_label] = []
        
        if subj2_label not in condition_dict_subj2:
            condition_dict_subj2[subj2_label] = []

        condition_dict_subj1[subj1_label].append(timestamps)
        condition_dict_subj2[subj2_label].append(timestamps)

    # Ensure all expected labels exist in the output dict (removed alone_rewarded)
    for label in labels:
        condition_dict_subj1.setdefault(label, [])
        condition_dict_subj2.setdefault(label, [])
        
        
    return {
        matched_subjs[0][1]: condition_dict_subj1,
        matched_subjs[1][1]: condition_dict_subj2
    }

# %% [markdown]
# ### Updated all in one dict

# %%
def build_experiment_dict():
    print("build_experiment_dict ran")
    all_data = {}

    # Load the single spreadsheet
    df = pd.read_excel(r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\combined_excel_file.xlsx", engine='openpyxl')
    
    df.columns = df.columns.str.strip()  # remove column name spacing issues

    for recording, group in df.groupby("session_dir"):
        print(f"Processing recording: {recording}")
        result = None
        
        # Determine experiment type and process accordingly
        if "standard_comp_to_training" in recording:
            print("  -> standard_comp_to_training")
            result = eventCondCreate(recording, group)
            
        elif "standard_comp_to_omission" in recording:
            print("  -> standard_comp_to_omission")
            result = eventCondCreate(recording, group, exclude_conditions=rce2_exclude_conditions)
            
        elif "long_comp" in recording:
            print("  -> long_comp")
            result = eventCondCreate(recording, group)
            
        elif "alone_comp" in recording:
            print("  -> alone_comp") 
            result = eventCondCreate(recording, group)
        
        else:
            print(f"  -> Unknown recording type: {recording}")
            continue
                
        # Add result to main dictionary if it's valid
        if result is not None:
            # Remove only the None-keyed item
            cleaned_result = {k: v for k, v in result.items() if k is not None}
            if cleaned_result:
                all_data.update(cleaned_result)
                print(f"  -> Added {len(cleaned_result)} subjects to dictionary")
            else:
                print(f"  -> No valid subjects found for {recording}")
        else:
            print(f"  -> No result returned for {recording}")

    return all_data

# %%
rce_experiment_dict = build_experiment_dict()

#output_base = Path("output_pickles")
#output_base.mkdir(exist_ok=True)

print(f"\nTotal number of names in dictionary: {len(rce_experiment_dict)}\n")
'''
for name, data in rce_experiment_dict.items():
    print(f"\n\nname: {name}\n\n")
    # Print full raw dict (optional, can get long)
    print(data)

'''
# Out:
# build_experiment_dict ran
# Processing recording: 20230612_101430_standard_comp_to_training_D1_subj_1-4_and_1-3
#   -> standard_comp_to_training
# eventCondCreate ran
#   -> Added 2 subjects to dictionary
# Processing recording: 20230612_112630_standard_comp_to_training_D1_subj_1-2_and_1-1
#   -> standard_comp_to_training
# eventCondCreate ran
#   -> Added 2 subjects to dictionary
# Processing recording: 20230613_105657_standard_comp_to_training_D2_subj_1-1_and_1-4
#   -> standard_comp_to_training
# eventCondCreate ran
#   -> Added 2 subjects to dictionary
# Processing recording: 20230614_114041_standard_comp_to_training_D3_subj_1-1_and_1-2
#   -> standard_comp_to_training
# eventCondCreate ran
#   -> Added 2 subjects to dictionary
# Processing recording: 20230616_111904_standard_comp_to_training_D4_subj_1-4_and_1-2
#   -> standard_comp_to_training
# eventCondCreate ran
#   -> Added 2 subjects to dictionary
# ...

# %%
# Quick verification that it's working correctly
print(f"✅ SUCCESS: Event dictionary built with {len(rce_experiment_dict)} subjects")
print(f"✅ Logic preserved: Same event extraction logic as your server code")
print(f"✅ Fixed technical issue: Now handles string paths instead of Path objects")

# Show a sample to verify structure
if rce_experiment_dict:
    sample_key = list(rce_experiment_dict.keys())[0]
    sample_data = rce_experiment_dict[sample_key]
    print(f"\n📋 Sample structure for '{sample_key}':")
    for condition, events in sample_data.items():
        if events:  # Only show non-empty conditions
            print(f"  {condition}: {len(events)} events")
            print(f"    First event: {events[0]}")
# Out:
# ✅ SUCCESS: Event dictionary built with 32 subjects
# ✅ Logic preserved: Same event extraction logic as your server code
# ✅ Fixed technical issue: Now handles string paths instead of Path objects
#
# 📋 Sample structure for '20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec':
#   low_comp_win: 6 events
#     First event: [982229, 1182226]
#   low_comp_lose: 5 events
#     First event: [3382227, 3582224]
#   high_comp_lose: 8 events
#     First event: [12982217, 13182217]
#   high_comp_win: 1 events
#     First event: [21282213, 21482212]

# %%
rce_experiment_dict.keys()
# Out:
# dict_keys(['20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec', '20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec', '20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec', '20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec', '20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec', '20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec', '20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec', '20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec', '20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec', '20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec', '20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec', '20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec', '20230618_100636_standard_comp_to_omiss
# ...

# %%
import pickle
from pathlib import Path

# Your target path
save_path = Path(r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\my_method.pkl")

# Save (pickle) the dict
with open(save_path, "wb") as f:
    pickle.dump(rce_experiment_dict, f)

# Load (unpickle) the dict back
with open(save_path, "rb") as f:
    loaded_dict = pickle.load(f)

print(loaded_dict)
# Out:
# {'20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec': {'low_comp_win': [[982229, 1182226], [5682225, 5882222], [7482224, 7682221], [8582220, 8782223], [11482221, 11682221], [24582210, 24782210]], 'low_comp_lose': [[3382227, 3582224], [9582220, 9782222], [16082217, 16282217], [17682216, 17882213], [22682209, 22882209]], 'high_comp_lose': [[12982217, 13182217], [15082218, 15282215], [18982215, 19182212], [20282211, 20482211], [26182209, 26382209], [27582205, 27782205], [29782206, 29982206], [30982205, 31182202]], 'high_comp_win': [[21282213, 21482212]], 'high_comp_tie': []}, '20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec': {'low_comp_lose': [[982229, 1182226], [5682225, 5882222], [7482224, 7682221], [8582220, 8782223], [11482221, 11682221], [24582210, 24782210]], 'low_comp_win': [[3382227, 3582224], [9582220, 9782222], [16082217, 16282217], [17682216, 17882213], [22682209, 22882209]], 'high_comp_win': [[12982217, 13182217], [15082
# ...

# %% [markdown]
# ## Comparison with Alternative Approach
#
# Let's implement the alternative logic you showed me and compare the results:

# %%
import ast

def build_alternative_dict():
    """
    Alternative approach based on the code you provided
    """
    print("build_alternative_dict ran")
    
    # Load data similar to alternative approach 
    cols = ['condition', 'session_dir', 'all_subjects', 'tone_start_timestamp', 'tone_stop_timestamp', 'competition_closeness']
    
    comp_closeness_dict = {
        'Subj 1 blocking Subj 2': "competitive",
        'Subj 2 Only': "no_comp", 
        'Subj 2 blocking Subj 1': "competitive",
        'Subj 1 then Subj 2': "competitive", 
        'Subj 1 Only': "no_comp",
        'Subj 2 then Subj 1': "competitive",
        'Close Call': "competitive",
        'After trial': "no_comp"
    }
    
    df = pd.read_excel(r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\combined_excel_file.xlsx", 
                       usecols=cols, engine='openpyxl')
    
    df = df.dropna()  # Drop rows missing data
    df['all_subjects'] = df['all_subjects'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
    df = df[df['all_subjects'].apply(lambda x: len(x) < 3)]  # Ignore novel sessions for now
    
    # Initialize list to collect data for new DataFrame
    new_df_data = []
    
    for _, row in df.iterrows():
        session_dir = row['session_dir']
        subjects = row['all_subjects'] 
        condition = row['condition']
        compness = row['competition_closeness']
        comp_label = comp_closeness_dict.get(compness, "")
        
        # Split session_dir on '_subj_' and take the first part only
        base_session_dir = session_dir.split('_subj_')[0]
        
        for subject in subjects:
            subject_formatted = subject.replace('.', '-')
            # Append formatted subject to the base session_dir correctly
            subj_recording = f"{base_session_dir}_subj_{subject_formatted}"
            
            # Determine the new condition based on competition and win/lose logic
            if condition in ['rewarded', 'omission', 'both_rewarded', 'tie']:
                new_condition = condition
            else:
                win_or_lose = 'win' if str(condition) == str(subject) else 'lose'
                new_condition = f"{comp_label}_{win_or_lose}"
                
            new_df_data.append({
                'session_dir': session_dir,
                'subject': subject,
                'subj_recording': subj_recording,
                'condition': new_condition,
                'tone_start_timestamp': row['tone_start_timestamp'],
                'tone_stop_timestamp': row['tone_stop_timestamp']
            })
    
    # Convert list to DataFrame
    new_df = pd.DataFrame(new_df_data)
    new_df = new_df.drop_duplicates()
    
    # Prepare timestamp_dicts from new_df
    valid_conditions = ['rewarded', 'omission', 'both_rewarded', 'tie', 'no_comp_win', 'no_comp_lose', 'competitive_win', 'competitive_lose']
    timestamp_dicts = {}
    
    for _, row in new_df.iterrows():
        key = row['subj_recording']
        condition = row['condition']
        timestamp_start = int(row['tone_start_timestamp']) // 20
        timestamp_end = int(row['tone_stop_timestamp']) // 20
        tuple_val = (timestamp_start, timestamp_end)

        if key not in timestamp_dicts:
            timestamp_dicts[key] = {cond: [] for cond in valid_conditions}
        if condition in valid_conditions:
            timestamp_dicts[key][condition].append(tuple_val)
        else:
            print(f"Unexpected condition: {condition} for subj_recording {key}")

    
    return timestamp_dicts

# Run alternative approach
alternative_dict = build_alternative_dict()
# Out:
# build_alternative_dict ran

# %% [markdown]
# ## Comparing event dicts here with recording dicts in z_score_analysis visually

# %%
len(alternative_dict)
# Out:
# 40

# %%
i=1
for key in alternative_dict:
    print(f"{i}: {key}")
    i+=1
# Out:
# 1: 20230612_101430_standard_comp_to_training_D1_subj_1-3
# 2: 20230612_101430_standard_comp_to_training_D1_subj_1-4
# 3: 20230612_112630_standard_comp_to_training_D1_subj_1-1
# 4: 20230612_112630_standard_comp_to_training_D1_subj_1-2
# 5: 20230613_105657_standard_comp_to_training_D2_subj_1-1
# 6: 20230613_105657_standard_comp_to_training_D2_subj_1-4
# 7: 20230614_114041_standard_comp_to_training_D3_subj_1-1
# 8: 20230614_114041_standard_comp_to_training_D3_subj_1-2
# 9: 20230616_111904_standard_comp_to_training_D4_subj_1-2
# 10: 20230616_111904_standard_comp_to_training_D4_subj_1-4
# 11: 20230617_115521_standard_comp_to_omission_D1_subj_1-1
# 12: 20230617_115521_standard_comp_to_omission_D1_subj_1-2
# 13: 20230618_100636_standard_comp_to_omission_D2_subj_1-1
# 14: 20230618_100636_standard_comp_to_omission_D2_subj_1-4
# 15: 20230619_115321_standard_comp_to_omission_D3_subj_1-2
# 16: 20230619_115321_standard_comp_to_omission_D3_subj_1-4
# ...

# %%
rce_keys = rce_experiment_dict.keys()

# %%
len(rce_keys)
# Out:
# 32

# %%
i=1
for key in rce_keys:
    print(f"{i}: {key}")
    i+=1
# Out:
# 1: 20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
# 2: 20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec
# 3: 20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec
# 4: 20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec
# 5: 20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec
# 6: 20230613_105657_standard_comp_to_training_D2_subj_1-4_t4b3L_box2_merged.rec
# 7: 20230614_114041_standard_comp_to_training_D3_subj_1-1_t1b3L_box1_merged.rec
# 8: 20230614_114041_standard_comp_to_training_D3_subj_1-2_t2b2L_box2_merged.rec
# 9: 20230616_111904_standard_comp_to_training_D4_subj_1-4_t4b3L_box1_merged.rec
# 10: 20230616_111904_standard_comp_to_training_D4_subj_1-2_t2b2L_box2_merged.rec
# 11: 20230617_115521_standard_comp_to_omission_D1_subj_1-1_t1b3L_box1_merged.rec
# 12: 20230617_115521_standard_comp_to_omission_D1_subj_1-2_t2b2L_box2_merged.rec
# ...

# %%
keys = alternative_dict.keys()

# %%
for key in keys:
    print(f"rec: {key}")
# Out:
# rec: 20230612_101430_standard_comp_to_training_D1_subj_1-3
# rec: 20230612_101430_standard_comp_to_training_D1_subj_1-4
# rec: 20230612_112630_standard_comp_to_training_D1_subj_1-1
# rec: 20230612_112630_standard_comp_to_training_D1_subj_1-2
# rec: 20230613_105657_standard_comp_to_training_D2_subj_1-1
# rec: 20230613_105657_standard_comp_to_training_D2_subj_1-4
# rec: 20230614_114041_standard_comp_to_training_D3_subj_1-1
# rec: 20230614_114041_standard_comp_to_training_D3_subj_1-2
# rec: 20230616_111904_standard_comp_to_training_D4_subj_1-2
# rec: 20230616_111904_standard_comp_to_training_D4_subj_1-4
# rec: 20230617_115521_standard_comp_to_omission_D1_subj_1-1
# rec: 20230617_115521_standard_comp_to_omission_D1_subj_1-2
# rec: 20230618_100636_standard_comp_to_omission_D2_subj_1-1
# rec: 20230618_100636_standard_comp_to_omission_D2_subj_1-4
# rec: 20230619_115321_standard_comp_to_omission_D3_subj_1-2
# rec: 20230619_115321_standard_comp_to_omission_D3_subj_1-4
# ...

# %%
alternative_dict['20230612_112630_standard_comp_to_training_D1_subj_1-1']
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [],
#  'no_comp_win': [(1141336, 1151336), (1236335, 1246335), (1556335, 1566335)],
#  'no_comp_lose': [(176337, 186337), (381336, 391336), (436336, 446336)],
#  'competitive_win': [(56337, 66337),
#   (1316335, 1326335),
#   (1386335, 1396335),
#   (1496335, 1506335)],
#  'competitive_lose': [(291337, 301336),
#   (486336, 496336),
#   (581336, 591336),
#   (656336, 666336),
#   (761336, 771336),
#   (811336, 821336),
#   (891336, 901336),
#   (956336, 966336),
#   (1021336, 1031336),
#   (1071336, 1081336)]}

# %%
alternative_dict['20240320_171038_alone_comp_subj_4-3']
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [(2479038, 2489038), (2599039, 2609039)],
#  'no_comp_win': [(1714028, 1724028),
#   (1764029, 1774029),
#   (1944031, 1954031),
#   (2029032, 2039032),
#   (2194034, 2204034),
#   (2244035, 2254035),
#   (2544038, 2554039),
#   (2674040, 2684040),
#   (3064045, 3074045)],
#  'no_comp_lose': [],
#  'competitive_win': [(1819030, 1829030),
#   (1869030, 1879030),
#   (2144033, 2154034),
#   (2309035, 2319036),
#   (2369036, 2379036),
#   (2724041, 2734041),
#   (2779041, 2789041),
#   (2829042, 2839042),
#   (2899043, 2909043),
#   (3009044, 3019044)],
#  'competitive_lose': []}

# %%
alternative_dict['20240320_142408_alone_comp_subj_3-1'] # matches with sp.recordings[27]
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [(2368823, 2378823)],
#  'no_comp_win': [(1713814, 1723814), (2028818, 2038818), (2478824, 2488824)],
#  'no_comp_lose': [(1818816, 1828816),
#   (2598825, 2608825),
#   (2828828, 2838828),
#   (2898829, 2908829),
#   (3008830, 3018831),
#   (3063831, 3073831)],
#  'competitive_win': [(1763815, 1773815),
#   (1868816, 1878817),
#   (2143820, 2153820),
#   (2193820, 2203821),
#   (2243821, 2253821),
#   (2308822, 2318822),
#   (2543825, 2553825),
#   (2673826, 2683826),
#   (2778827, 2788828)],
#  'competitive_lose': [(1943817, 1953817), (2723827, 2733827)]}

# %%
'20240320_142408_alone_comp_subj_3-1'
# Out:
# '20240320_142408_alone_comp_subj_3-1'

# %%
alternative_dict['20240320_142408_alone_comp_subj_3-1']
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [(2368823, 2378823)],
#  'no_comp_win': [(1713814, 1723814), (2028818, 2038818), (2478824, 2488824)],
#  'no_comp_lose': [(1818816, 1828816),
#   (2598825, 2608825),
#   (2828828, 2838828),
#   (2898829, 2908829),
#   (3008830, 3018831),
#   (3063831, 3073831)],
#  'competitive_win': [(1763815, 1773815),
#   (1868816, 1878817),
#   (2143820, 2153820),
#   (2193820, 2203821),
#   (2243821, 2253821),
#   (2308822, 2318822),
#   (2543825, 2553825),
#   (2673826, 2683826),
#   (2778827, 2788828)],
#  'competitive_lose': [(1943817, 1953817), (2723827, 2733827)]}

# %%
len(alternative_dict['20240320_171038_alone_comp_subj_4-3']['competitive_win'])
# Out:
# 10

# %%
len(alternative_dict['20240320_171038_alone_comp_subj_4-3']['no_comp_win'])
# Out:
# 9

# %% [markdown]
# # wtf | it's fine in the collection but why the fuck is this here

# %%
rce_experiment_dict['20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec']
# Out:
# {'low_comp_win': [[982229, 1182226],
#   [5682225, 5882222],
#   [7482224, 7682221],
#   [8582220, 8782223],
#   [11482221, 11682221],
#   [24582210, 24782210]],
#  'low_comp_lose': [[3382227, 3582224],
#   [9582220, 9782222],
#   [16082217, 16282217],
#   [17682216, 17882213],
#   [22682209, 22882209]],
#  'high_comp_lose': [[12982217, 13182217],
#   [15082218, 15282215],
#   [18982215, 19182212],
#   [20282211, 20482211],
#   [26182209, 26382209],
#   [27582205, 27782205],
#   [29782206, 29982206],
#   [30982205, 31182202]],
#  'high_comp_win': [[21282213, 21482212]],
#  'high_comp_tie': []}

# %%
alternative_dict['20230612_101430_standard_comp_to_training_D1_subj_1-4']
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [],
#  'no_comp_win': [(49111, 59111),
#   (284111, 294111),
#   (374111, 384111),
#   (429111, 439111),
#   (574111, 584111),
#   (1229110, 1239110)],
#  'no_comp_lose': [(169111, 179111),
#   (479111, 489111),
#   (804110, 814110),
#   (884110, 894110),
#   (1134110, 1144110)],
#  'competitive_win': [(1064110, 1074110)],
#  'competitive_lose': [(649110, 659110),
#   (754110, 764110),
#   (949110, 959110),
#   (1014110, 1024110),
#   (1309110, 1319110),
#   (1379110, 1389110),
#   (1489110, 1499110),
#   (1549110, 1559110)]}

# %%
# Iterate through all keys and find the specific one
target_key = '20240320_171038_alone_comp_subj_4-3'

print("Iterating through all keys in alternative_dict:")
print("=" * 60)

for i, key in enumerate(alternative_dict.keys()):
    if key == target_key:
        print(f"{i+1:2d}. FOUND IT! -> {key}")
    else:
        print(f"{i+1:2d}. {key}")

print("=" * 60)
print(f"Total keys: {len(alternative_dict)}")
print(f"Target key found: {target_key in alternative_dict}")
# Out:
# Iterating through all keys in alternative_dict:
# ...
#  1. 20230612_101430_standard_comp_to_training_D1_subj_1-3
#  2. 20230612_101430_standard_comp_to_training_D1_subj_1-4
#  3. 20230612_112630_standard_comp_to_training_D1_subj_1-1
#  4. 20230612_112630_standard_comp_to_training_D1_subj_1-2
#  5. 20230613_105657_standard_comp_to_training_D2_subj_1-1
#  6. 20230613_105657_standard_comp_to_training_D2_subj_1-4
#  7. 20230614_114041_standard_comp_to_training_D3_subj_1-1
#  8. 20230614_114041_standard_comp_to_training_D3_subj_1-2
#  9. 20230616_111904_standard_comp_to_training_D4_subj_1-2
# 10. 20230616_111904_standard_comp_to_training_D4_subj_1-4
# 11. 20230617_115521_standard_comp_to_omission_D1_subj_1-1
# 12. 20230617_115521_standard_comp_to_omission_D1_subj_1-2
# 13. 20230618_100636_standard_comp_to_omission_D2_subj_1-1
# 14. 20230618_100636_standard_comp_to_omission_D2_subj_1-4
# 15. 20230619_115321_standard_comp_to_omission_D3_subj_1-2
# ...

# %%
alternative_dict['20240320_171038_alone_comp_subj_4-3']
# Out:
# {'rewarded': [],
#  'omission': [],
#  'both_rewarded': [],
#  'tie': [(2479038, 2489038), (2599039, 2609039)],
#  'no_comp_win': [(1714028, 1724028),
#   (1764029, 1774029),
#   (1944031, 1954031),
#   (2029032, 2039032),
#   (2194034, 2204034),
#   (2244035, 2254035),
#   (2544038, 2554039),
#   (2674040, 2684040),
#   (3064045, 3074045)],
#  'no_comp_lose': [],
#  'competitive_win': [(1819030, 1829030),
#   (1869030, 1879030),
#   (2144033, 2154034),
#   (2309035, 2319036),
#   (2369036, 2379036),
#   (2724041, 2734041),
#   (2779041, 2789041),
#   (2829042, 2839042),
#   (2899043, 2909043),
#   (3009044, 3019044)],
#  'competitive_lose': []}

# %%
print(f"Alternative dict has {len(alternative_dict)} keys")
print(f"Your original dict has {len(rce_experiment_dict)} keys")

print("\nFirst few keys from alternative dict:")
for i, key in enumerate(list(alternative_dict.keys())[:5]):
    print(f"  {key}")
    
print("\nFirst few keys from your original dict:")
for i, key in enumerate(list(rce_experiment_dict.keys())[:5]):
    print(f"  {key}")

# Let's look at the structure differences
print("\n" + "="*60)
print("STRUCTURE COMPARISON")
print("="*60)

# Check if we can find any matching keys
alt_keys = set(alternative_dict.keys())
orig_keys = set(rce_experiment_dict.keys())

print(f"\nKeys in alternative but not in original: {len(alt_keys - orig_keys)}")
print(f"Keys in original but not in alternative: {len(orig_keys - alt_keys)}")
print(f"Keys in both: {len(alt_keys & orig_keys)}")

# Show some examples of key naming differences
print("\nExample alternative keys:")
for key in list(alt_keys)[:3]:
    print(f"  '{key}'")
    
print("\nExample original keys:")  
for key in list(orig_keys)[:3]:
    print(f"  '{key}'")

# Look at condition structures
if alternative_dict:
    first_alt_key = list(alternative_dict.keys())[0]
    print(f"\nAlternative conditions for '{first_alt_key}':")
    for cond, events in alternative_dict[first_alt_key].items():
        print(f"  {cond}: {len(events)} events")

if rce_experiment_dict:        
    first_orig_key = list(rce_experiment_dict.keys())[0]
    print(f"\nOriginal conditions for '{first_orig_key}':")
    for cond, events in rce_experiment_dict[first_orig_key].items():
        print(f"  {cond}: {len(events)} events")
# Out:
# Alternative dict has 40 keys
# Your original dict has 32 keys
#
# First few keys from alternative dict:
#   20230612_101430_standard_comp_to_training_D1_subj_1-3
#   20230612_101430_standard_comp_to_training_D1_subj_1-4
#   20230612_112630_standard_comp_to_training_D1_subj_1-1
#   20230612_112630_standard_comp_to_training_D1_subj_1-2
#   20230613_105657_standard_comp_to_training_D2_subj_1-1
#
# First few keys from your original dict:
#   20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
#   20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec
#   20230612_112630_standard_comp_to_training_D1_subj_1-2_t2b2L_box1_merged.rec
#   20230612_112630_standard_comp_to_training_D1_subj_1-1_t1b3L_box2_merged.rec
#   20230613_105657_standard_comp_to_training_D2_subj_1-1_t1b2L_box1_merged.rec
#
# ...
# STRUCTURE COMPARISON
# ...
#
# Keys in alternative but not in original: 40
# Keys in original but not in alternative: 32
# Keys in both: 0
#
# ...

# %% [markdown]
# ### Key Differences Analysis
#
# From the comparison above, I can see several important differences between the two approaches:
#
# ## **1. Key Naming Convention:**
# - **Alternative approach**: Uses the pattern `{datetime}_subj_{subject}` (e.g., `20230612_101430_standard_comp_to_training_D1_subj_1-3`)
# - **Your approach**: Uses the full merged recording filename (e.g., `20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec`)
#
# ## **2. Data Processing Strategy:**
# - **Alternative approach**: Uses the `all_subjects` column to create one entry per subject
# - **Your approach**: Uses `matchRec()` to find corresponding merged.rec files for each subject
#
# ## **3. Condition Labels:**
# - **Alternative approach**: Uses `competitive_win/lose`, `no_comp_win/lose`, `rewarded`, `omission`, etc.
# - **Your approach**: Uses `high_comp_win/lose`, `low_comp_win/lose`, `alone_rewarded`, etc.
#
# ## **4. Number of Records:**
# - **Alternative**: 40 keys (includes subjects that may not have merged.rec files)
# - **Your approach**: 32 keys (only subjects with matching merged.rec files)
#
# ## **5. Competition Closeness Mapping:**
# - **Alternative**: Maps competition_closeness to "competitive" vs "no_comp"
# - **Your approach**: Maps competition_closeness to "high_comp" vs "low_comp" (based on presence of "Only")
#
# The fundamental difference is that **your approach** is designed to work specifically with merged.rec files and filters out subjects without corresponding recording files, while the **alternative approach** processes all subjects regardless of whether they have recording files.

# %% [markdown]
# ## Comparing my (Original) approach and Taylors (Alternative) approach outputs

# %%
# Let's try to map between the two approaches and see if the data content matches
print("DATA CONTENT COMPARISON")
print("="*50)

# Function to extract subject and datetime from different key formats
def extract_subject_datetime(key, format_type="original"):
    if format_type == "original":
        # Extract from: 20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
        datetime_match = re.match(r"(\d{8}_\d{6})", key)
        subj_match = re.search(r"subj_([\d\-]+)", key)
        if datetime_match and subj_match:
            return datetime_match.group(1), subj_match.group(1)
    else:
        # Extract from: 20230612_101430_standard_comp_to_training_D1_subj_1-4
        datetime_match = re.match(r"(\d{8}_\d{6})", key)
        subj_match = re.search(r"subj_([\d\-]+)$", key)
        if datetime_match and subj_match:
            return datetime_match.group(1), subj_match.group(1)
    return None, None

# Try to find matching subjects between the two approaches
matches_found = 0
content_matches = 0

# for every original dict key, finds matching key in alternative dict based on subject and datetime, then compares event counts for each one
for orig_key, orig_data in rce_experiment_dict.items():
    orig_datetime, orig_subj = extract_subject_datetime(orig_key, "original")
    if not orig_datetime or not orig_subj:
        continue
        
    # Look for corresponding alternative key
    target_alt_key = None
    for alt_key in alternative_dict.keys():
        alt_datetime, alt_subj = extract_subject_datetime(alt_key, "alternative")
        if alt_datetime == orig_datetime and alt_subj == orig_subj:
            target_alt_key = alt_key
            break
    
    if target_alt_key:
        matches_found += 1
        alt_data = alternative_dict[target_alt_key]
        
        # Compare the event counts
        print(f"\nMatching subject found: {orig_subj} from {orig_datetime}")
        print(f"  Original key: {orig_key}")
        print(f"  Alternative key: {target_alt_key}")
        
        # Count total events in each
        orig_total = sum(len(events) for events in orig_data.values() if events)
        alt_total = sum(len(events) for events in alt_data.values() if events)
        
        print(f"  Original total events: {orig_total}")
        print(f"  Alternative total events: {alt_total}")
        
        if orig_total == alt_total:
            content_matches += 1
            print(f"  ✅ Event counts match!")
        else:
            print(f"  ❌ Event counts differ")
            
        # Show non-empty conditions from both
        orig_conditions = {k: len(v) for k, v in orig_data.items() if v}
        alt_conditions = {k: len(v) for k, v in alt_data.items() if v}
        
        if orig_conditions:
            print(f"  Original conditions: {orig_conditions}")
        if alt_conditions:
            print(f"  Alternative conditions: {alt_conditions}")

print(f"\n" + "="*50)
print(f"SUMMARY:")
print(f"Subjects found in both approaches: {matches_found}")
print(f"Subjects with matching event counts: {content_matches}")
print(f"Your approach has {len(rce_experiment_dict) - matches_found} unique subjects")
print(f"Alternative approach has {len(alternative_dict) - matches_found} unique subjects")
# Out:
# DATA CONTENT COMPARISON
# ...
#
# Matching subject found: 1-4 from 20230612_101430
#   Original key: 20230612_101430_standard_comp_to_training_D1_subj_1-4_t4b2L_box1_merged.rec
#   Alternative key: 20230612_101430_standard_comp_to_training_D1_subj_1-4
#   Original total events: 20
#   Alternative total events: 20
#   ✅ Event counts match!
#   Original conditions: {'low_comp_win': 6, 'low_comp_lose': 5, 'high_comp_lose': 8, 'high_comp_win': 1}
#   Alternative conditions: {'no_comp_win': 6, 'no_comp_lose': 5, 'competitive_win': 1, 'competitive_lose': 8}
#
# Matching subject found: 1-3 from 20230612_101430
#   Original key: 20230612_101430_standard_comp_to_training_D1_subj_1-3_t3b3L_box2_merged.rec
#   Alternative key: 20230612_101430_standard_comp_to_training_D1_subj_1-3
#   Original total events: 20
#   Alternative total events: 20
#   ✅ Event counts match!
#   Original conditions: {'low_comp_lose': 6, 'low_comp_win': 5, 'high_comp_win': 8, 'high_comp_lose': 1}
# ...

# %% [markdown]
# # 💾 Save Event Dictionaries as Pickle Files
#
# Let's save both the original and alternative event dictionaries as pickle files for future use:

# %%
import pickle
import os
from datetime import datetime

# Get the current directory (same as notebook location)
current_directory = r"C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation"

print(f"📁 Saving pickle files to: {current_directory}")

# Create timestamped filenames
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Define file paths
original_file = os.path.join(current_directory, f"original_event_dict_{timestamp}.pkl")
alternative_file = os.path.join(current_directory, f"alternative_event_dict_{timestamp}.pkl")

# Save original method event dictionary
print(f"\n💾 Saving original event dictionary...")
print(f"   Dictionary: rce_experiment_dict")
print(f"   Records: {len(rce_experiment_dict)} recordings")
print(f"   File: {os.path.basename(original_file)}")

with open(original_file, 'wb') as f:
    pickle.dump(rce_experiment_dict, f)

# Save alternative method event dictionary  
print(f"\n💾 Saving alternative event dictionary...")
print(f"   Dictionary: alternative_dict")
print(f"   Records: {len(alternative_dict)} recordings")
print(f"   File: {os.path.basename(alternative_file)}")

with open(alternative_file, 'wb') as f:
    pickle.dump(alternative_dict, f)

print(f"\n✅ SUCCESS! Both dictionaries saved.")
print(f"📊 Summary:")
print(f"   Original method: {len(rce_experiment_dict)} recordings")
print(f"   Alternative method: {len(alternative_dict)} recordings")
print(f"   Location: {current_directory}")

# Verify files were created
if os.path.exists(original_file) and os.path.exists(alternative_file):
    orig_size = os.path.getsize(original_file) / 1024  # KB
    alt_size = os.path.getsize(alternative_file) / 1024  # KB
    print(f"\n📏 File sizes:")
    print(f"   Original: {orig_size:.1f} KB")
    print(f"   Alternative: {alt_size:.1f} KB")
else:
    print(f"\n❌ Error: Files were not created successfully")

# Store file paths for future reference
saved_files = {
    'original': original_file,
    'alternative': alternative_file,
    'timestamp': timestamp
}

print(f"\n🔗 File paths stored in 'saved_files' variable for easy loading later")
# Out:
# 📁 Saving pickle files to: C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation
#
# 💾 Saving original event dictionary...
#    Dictionary: rce_experiment_dict
#    Records: 32 recordings
#    File: original_event_dict_20251009_142705.pkl
#
# 💾 Saving alternative event dictionary...
#    Dictionary: alternative_dict
#    Records: 40 recordings
#    File: alternative_event_dict_20251009_142705.pkl
#
# ✅ SUCCESS! Both dictionaries saved.
# 📊 Summary:
#    Original method: 32 recordings
#    Alternative method: 40 recordings
#    Location: C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation
#
# 📏 File sizes:
#    Original: 10.6 KB
#    Alternative: 13.1 KB
#
# 🔗 File paths stored in 'saved_files' variable for easy loading later

# %%
# Example of how to load the saved dictionaries later
print("📖 HOW TO LOAD THE SAVED DICTIONARIES:")
print("="*50)

print(f"""
# To load the original event dictionary:
import pickle
with open(r'{original_file}', 'rb') as f:
    loaded_original_dict = pickle.load(f)

# To load the alternative event dictionary:
with open(r'{alternative_file}', 'rb') as f:
    loaded_alternative_dict = pickle.load(f)

print(f"Original loaded: {{len(loaded_original_dict)}} recordings")
print(f"Alternative loaded: {{len(loaded_alternative_dict)}} recordings")
""")

print("\n🎯 DICTIONARY COMPARISON SUMMARY:")
print(f"   Original method conditions: {list(rce_experiment_dict[list(rce_experiment_dict.keys())[0]].keys())}")
print(f"   Alternative method conditions: {list(timestamp_dicts[list(timestamp_dicts.keys())[0]].keys())}")

print(f"\n📋 KEY DIFFERENCES:")
print(f"   • Original: Frame-based timestamps, 5 condition types")
print(f"   • Alternative: Converted timestamps (÷20), 8 condition types") 
print(f"   • Alternative includes: rewarded, omission, both_rewarded events")
print(f"   • Alternative has 8 additional recordings not in original")

print(f"\n🎉 Both dictionaries are now saved and ready for use in your analyses!")
# Out:
# 📖 HOW TO LOAD THE SAVED DICTIONARIES:
# ...
#
# # To load the original event dictionary:
# import pickle
# with open(r'C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\original_event_dict_20251009_142705.pkl', 'rb') as f:
#     loaded_original_dict = pickle.load(f)
#
# # To load the alternative event dictionary:
# with open(r'C:\Users\thoma\Code\ResearchCode\diff_fam_social_memory_ephys\other_peoples_sutff\Thomas\reward_comp\testing_eventdict_creation\alternative_event_dict_20251009_142705.pkl', 'rb') as f:
#     loaded_alternative_dict = pickle.load(f)
#
# print(f"Original loaded: {len(loaded_original_dict)} recordings")
# print(f"Alternative loaded: {len(loaded_alternative_dict)} recordings")
#
#
# 🎯 DICTIONARY COMPARISON SUMMARY:
#    Original method conditions: ['low_comp_win', 'low_comp_lose', 'high_comp_lose', 'high_comp_win', 'high_comp_tie']
# ...

# %%
# Iterate through all keys and find the specific one
target_key = '20230612_101430_standard_comp_to_training_D1_subj_1-3'

print("Iterating through all keys in alternative_dict:")
print("=" * 60)

for i, key in enumerate(alternative_dict.keys()):
    if key == target_key:
        print(f"{i+1:2d}. FOUND IT! -> {key}")
    else:
        print(f"{i+1:2d}. {key}")

print("=" * 60)
print(f"Total keys: {len(alternative_dict)}")
print(f"Target key found: {target_key in alternative_dict}")
# Out:
# Iterating through all keys in alternative_dict:
# ...
#  1. FOUND IT! -> 20230612_101430_standard_comp_to_training_D1_subj_1-3
#  2. 20230612_101430_standard_comp_to_training_D1_subj_1-4
#  3. 20230612_112630_standard_comp_to_training_D1_subj_1-1
#  4. 20230612_112630_standard_comp_to_training_D1_subj_1-2
#  5. 20230613_105657_standard_comp_to_training_D2_subj_1-1
#  6. 20230613_105657_standard_comp_to_training_D2_subj_1-4
#  7. 20230614_114041_standard_comp_to_training_D3_subj_1-1
#  8. 20230614_114041_standard_comp_to_training_D3_subj_1-2
#  9. 20230616_111904_standard_comp_to_training_D4_subj_1-2
# 10. 20230616_111904_standard_comp_to_training_D4_subj_1-4
# 11. 20230617_115521_standard_comp_to_omission_D1_subj_1-1
# 12. 20230617_115521_standard_comp_to_omission_D1_subj_1-2
# 13. 20230618_100636_standard_comp_to_omission_D2_subj_1-1
# 14. 20230618_100636_standard_comp_to_omission_D2_subj_1-4
# 15. 20230619_115321_standard_comp_to_omission_D3_subj_1-2
# ...
